# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
# %config InlineBackend.figure_format="retina"

# %%
np.power(2,4)
# Out:
# 16

# %%
t=np.linspace(0,8*np.pi,360*10)
x=np.sin(t)*(np.exp(np.cos(t))-2*np.cos(4*t)-np.sin(t/12)**5)
y=np.cos(t)*(np.exp(np.cos(t))-2*np.cos(4*t)-np.sin(t/12)**5)

# %%
plt.plot(x,y)

# %%
a=np.random.randint(1,100,12).reshape(3,4)
a
# Out:
# array([[16, 71, 95,  7],
#        [19, 89, 33, 96],
#        [46, 99, 52, 18]])

# %%
b=np.random.randint(1,100,12).reshape(3,4)
b
# Out:
# array([[83, 50, 46, 70],
#        [59, 13, 97, 36],
#        [88, 46, 40, 14]])

# %%
np.maximum(a,b)
# Out:
# array([[83, 71, 95, 70],
#        [59, 89, 97, 96],
#        [88, 99, 52, 18]])

# %%
np.pi
# Out:
# 3.141592653589793

# %%
np.add(a,b)
# Out:
# array([[ 99, 121, 141,  77],
#        [ 78, 102, 130, 132],
#        [134, 145,  92,  32]])

# %%
np.log(10)
# Out:
# 2.302585092994046

# %%
np.log10(10)
# Out:
# 1.0
