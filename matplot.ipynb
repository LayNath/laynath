# %%
import numpy as np
import matplotlib.pyplot as plt
# %config InlineBacken.figure_format='retina'
x=np.arange(0,100)
y=x*2
z=x**2

# %%
fig = plt.figure()
ax =fig.add_axes([0,0,1,1])
ax.plot(x,y)
# plt.plot(x,y)
ax.set_xlabel("x")
ax.set_ylabel("y")
ax.set_title('XY')
# Out:
# Text(0.5, 1.0, 'XY')

# %%
fig =plt.figure()
ax1 = fig.add_axes([0,0,1,1])
ax2 = fig.add_axes([0.2,0.5,.2,.2])
ax1.plot(x,y)
ax2.plot(x,y)

# %%
plt.subplots(1,2)
# Out:
# (<Figure size 432x288 with 2 Axes>,
#  array([<matplotlib.axes._subplots.AxesSubplot object at 0x7fe3682b7198>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7fe368235550>],
#        dtype=object))
